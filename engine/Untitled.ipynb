# %%
import pandas as pd
import math

# %%
df = pd.read_csv('Preprocessed_data.csv')

# %%
df.head(20)
# Out:
#     s.no  user_id                    location      age  rating  \
# 0      0        2   stockton, california, usa  18.0000       0
# 1      1        8    timmins, ontario, canada  34.7439       5
# 2     15        8    timmins, ontario, canada  34.7439       0
# 3     18        8    timmins, ontario, canada  34.7439       0
# 4     29        8    timmins, ontario, canada  34.7439       0
# 5     30        8    timmins, ontario, canada  34.7439       0
# 6     63        8    timmins, ontario, canada  34.7439       0
# 7     68        8    timmins, ontario, canada  34.7439       0
# 8     71        8    timmins, ontario, canada  34.7439       0
# 9     72        8    timmins, ontario, canada  34.7439       5
# 10    73        8    timmins, ontario, canada  34.7439       0
# 11    79        8    timmins, ontario, canada  34.7439       0
# 12    80        8    timmins, ontario, canada  34.7439       5
# 13    82        8    timmins, ontario, canada  34.7439       5
# ...
